# %% [markdown]
# # 1.

# %%
name1="nishant"
name2="chauhan"
print(name1+name2)
# Out:
# nishantchauhan

# %% [markdown]
# # 2.

# %% [markdown]
#  + operator assign  the value and join method join the two string with help of separator .separator like that "-"
# example.

# %%
a="nishant"
b="chauhan"
print(a+b)

name=("nishant","ayush","monika")
print("-".join(name))
# Out:
# nishantchauhan
# nishant-ayush-monika

# %% [markdown]
# # 3.

# %% [markdown]
# you can acees the individual characters with the help of indexing or methods.

# %%
data="hello"
data[1]
# Out:
# 'e'

# %% [markdown]
# # 4.

# %%
string="pyhton"
print(string)

# %% [markdown]
# # 5.

# %% [markdown]
# using a method of string.upper()

# %%
string="pyhton"
string.upper()
# Out:
# 'PYHTON'

# %% [markdown]
# # 6.

# %% [markdown]
# using a method of string.lower()

# %%
string="PYHTON"
string.lower()
# Out:
# 'pyhton'

# %% [markdown]
# # 7.

# %% [markdown]
# with the help of replace method .you can replace the substring.

# %%
string="pyhton"
string.replace("y","a")
# Out:
# 'pahton'

# %% [markdown]
# # 8.

# %%
string="pthon is language"
string.split(" ")
# Out:
# ['pthon', 'is', 'language']

# %% [markdown]
# # 9.

# %%
string = "java is a language"
string.startswith("java")
# Out:
# True

# %% [markdown]
#  # 10.

# %%
string = "python is a language"
string.endswith("language")
# Out:
# True

# %% [markdown]
# # 11.

# %%
string="  pyhton  "
string.strip(" ")
# Out:
# 'pyhton'

# %% [markdown]
# # 12.

# %%
string="mango"
string.index("a")
# Out:
# 1

# %% [markdown]
# # 13.

# %%
string="pyhtonnn"
string.count("n")
# Out:
# 3

# %% [markdown]
# # 14.

# %%
string="mango"
string.isalpha()
# Out:
# True

# %% [markdown]
# # 15.

# %%
string="mango123"
print(string.isnumeric())
data="1234"
print(data
    .isnumeric())
# Out:
# False
# True

# %% [markdown]
# # 16.

# %%
string="mom"
rev_string=string[::-1]
print(rev_string==string)
# Out:
# True

# %% [markdown]
# # 17.

# %%
string="pyhton"
string[::-1
    ]
# Out:
# 'nothyp'

# %% [markdown]
# # 18.

# %%
name="nishant"
age=20
print("my name is {} age is {}".format(name,age))
# Out:
# my name is nishant age is 20

# %% [markdown]
# # 19.

# %%
string=" my name is pyhton"
string[2:12:2]
# Out:
# 'ynm s'

# %% [markdown]
# # 20.

# %%
string="pyhton is happy"
string.replace("happy","")
# Out:
# 'pyhton is '
